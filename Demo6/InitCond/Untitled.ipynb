# %%
from swiftsimio import load
import h5py

# %%
# !pwd
# Out:
# /home/lacruzen/Desktop/swift-cmgi/Demo6/InitCond

# %%
# !ls
# Out:
# cmgi_impactor_n50.hdf5	    make_init_cond.py  snapshots
# cmgi_impactor_n50.yml	    output_n50_i.txt   statistics.txt
# cmgi_impactor_profile.hdf5  output_n50_t.txt   task_level_0.txt
# cmgi_target_n50.hdf5	    plot_profiles.py   timesteps.txt
# cmgi_target_n50.yml	    plot_snapshots.py  Untitled.ipynb
# cmgi_target_profile.hdf5    profiles	       unused_parameters.yml
# dependency_graph_0.csv	    restart	       used_parameters.yml
# make_impact_init_cond.py    run.sh

# %%
data = load("/home/lacruzen/Desktop/swift-cmgi/Demo6/InitCond/snapshots/cmgi_target_n50_0005.hdf5")

# %%
data
# Out:
# SWIFT dataset at /home/lacruzen/Desktop/swift-cmgi/Demo6/InitCond/snapshots/cmgi_target_n50_0005.hdf5.
# Available groups: gas

# %%
data.gas
# Out:
# SWIFT dataset at /home/lacruzen/Desktop/swift-cmgi/Demo6/InitCond/snapshots/cmgi_target_n50_0005.hdf5.
# Available fields: coordinates, densities, entropies, internal_energies, masses, material_ids, particle_ids, potentials, pressures, progenitor_particle_ids, smoothing_lengths, split_counts, split_trees, velocities
